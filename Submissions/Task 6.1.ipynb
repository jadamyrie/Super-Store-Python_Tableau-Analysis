# %%
import pandas as pd
import numpy as np
import os

# %%
# showing path
path = r'C:\Users\TEDWI\OneDrive\Project 6'

# %%
df_store = pd.read_csv(r'C:\Users\TEDWI\OneDrive\Project 6\train.csv',index_col= False)

# %% [markdown]
# ##Checking Store dataframe for missing values, inconsistencies and data wrangling

# %%
# showing first five rows of store dataframe
df_store.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# showing last five rows of store dataframe
df_store.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
# showing the number of rows and columns in store dataframe
df_store.shape
# Out:
# (9800, 18)

# %%
#removing region column
df_store = df_store.drop(columns = ['Region'])

# %%
# gathering more info on store  dataframe
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# ...

# %%
# descriptive statistics of store dataframe
df_store.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# checking for missing values in store dataframe
df_store.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ## There are 11 missing values from  column postal code in the dataset.

# %%
# missing values subsets
df_nan = df_store[df_store['Postal Code'].isnull()== True]

# %%
#view missing values
df_nan
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
# cleaning Postal Code column
df_store_clean = df_store[df_store['Postal Code'].isnull()== False]

# %%
# viewing column
df_store_clean
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# viewing new shape
df_store_clean.shape
# Out:
# (9789, 17)

# %%
# removing na values
df_store.dropna( inplace = True)

# %%
df_store.dropna(subset=['Postal Code'], inplace = True)

# %%
# checking for duplicates
df_store_dups = df_store_clean[df_store_clean.duplicated()]

# %%
df_store_dups
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %%
# changing customer name column from object type to str
df_store['Customer Name']= df_store['Customer Name'].astype('str')

# %% [markdown]
# no duplicates are in the dataset

# %%
#checking for mixed type columns in store data frame
for col in df_store_clean.columns.tolist():
  weird = (df_store_clean[[col]].applymap(type) != df_store_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_store_clean[weird]) > 0:
    print (col)

# %%
# remove what is below

# %%
sorted(df_store['Postal Code'].unique())
# Out:
# [1040.0,
#  1453.0,
#  1752.0,
#  1810.0,
#  1841.0,
#  1852.0,
#  1915.0,
#  2038.0,
#  2138.0,
#  2148.0,
#  2149.0,
#  2151.0,
#  2169.0,
#  2740.0,
#  2886.0,
#  2895.0,
#  2908.0,
#  2920.0,
#  3060.0,
#  3301.0,
#  3820.0,
#  4240.0,
#  4401.0,
#  6010.0,
#  6040.0,
#  6360.0,
#  6450.0,
#  6457.0,
#  6460.0,
#  6484.0,
#  6708.0,
#  6810.0,
#  6824.0,
#  7002.0,
#  7011.0,
#  7017.0,
#  7036.0,
#  7050.0,
#  7055.0,
#  7060.0,
#  7090.0,
#  7109.0,
#  7501.0,
#  7601.0,
#  7960.0,
#  8302.0,
#  8360.0,
#  8401.0,
#  8701.0,
#  8861.0,
#  8901.0,
#  10009.0,
#  10011.0,
#  10024.0,
#  10035.0,
#  10550.0,
#  10701.0,
#  10801.0,
#  11520.0,
#  11550.0,
#  11561.0,
#  11572.0,
#  11757.0,
#  12180.0,
#  13021.0,
#  13440.0,
#  13501.0,
#  13601.0,
#  14215.0,
#  14304.0,
#  14609.0,
#  14701.0,
#  16602.0,
#  17403.0,
#  17602.0,
#  18018.0,
#  18103.0,
#  19013.0,
#  19120.0,
#  19134.0,
#  19140.0,
#  19143.0,
#  19601.0,
#  19711.0,
#  19805.0,
#  19901.0,
#  20016.0,
# ...

# %%
df_store= df_store[df_store['Postal Code'].notna()]
df_store['Postal Code'].isna().any()
# Out:
# False

# %%
df_store['Postal Code']=df_store['Postal Code'].astype(int)

# %%
df_store = df_store.drop(columns = ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment','Country',
           'City', 'State', 'Product ID', 'Category', 'Sub-Category', 'Product Name'], axis=1)

# %%
df_store.head()
# Out:
#    Postal Code     Sales
# 0        42420  261.9600
# 1        42420  731.9400
# 2        90036   14.6200
# 3        33311  957.5775
# 4        33311   22.3680

# %% [markdown]
# no mixed type data is in the dataset

# %%
# exporting file as a pickle
df_store_clean.to_pickle(os.path.join(path, 'df_store_new.pkl'))
